# %%
# !pip install streamlit
# !pip install pyngrok==4.1.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 47.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15963 sha256=6b54bedec108e3b6eb12118db03cbab46ecd14a7056353d708b50d879f664dce
#   Stored in directory: /root/.cache/pip/wheels/4c/7c/4c/632fba2ea8e88d8890102eb07bc922e1ca8fa14db5902c91a8
# Successfully built pyngrok
# ...

# %%
# %%writefile streamlit_app.py
# Out:
# Writing streamlit_app.py

# %%
import streamlit as st
from pyngrok import ngrok

# %%
# !sudo apt update
# !sudo apt install ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,302 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,550 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,538 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,277 kB]
# ...

# %%
#connecting google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# !bash Miniconda3-py37_4.9.2-Linux-x86_64.sh -bfp /usr/local

# Step 2: Set up Conda
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages')

# %%
# !conda env create -f environment.yml
# !conda activate mdm
# !python -m spacy download en_core_web_sm
# !pip install git+https://github.com/openai/CLIP.git

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/motion-diffusion-model-main')
print(os.getcwd())

# %%
# !bash prepare/download_smpl_files.sh
# !bash prepare/download_glove.sh
# !bash prepare/download_t2m_evaluators.sh

# %%
#!cd motion-diffusion-model

# %%
# !pip install smplx
# !pip install matplotlib
# !pip install spacy
# !pip install chumpy

# %%
#!pip uninstall typing_extensions --yes
# !pip install typing_extensions==4.7.1

# %%
#!yes|pip uninstall clip

# %%
#!pip install openai-clip

# %%
# !pip install torchvision

# %%
# !pip install basemap

# %%
# Your Streamlit app code here
def main():
    st.title("Avatar Generation")
    if st.button("Generate Avatar"):
        # !python -m sample.generate --model_path /content/drive/MyDrive/motion-diffusion-model-main/save/humanml_trans_enc_512/model000200000.pt --text_prompt "the person is hopping like a rabbit"
        # !python -m visualize.render_mesh --input_path /content/drive/MyDrive/motion-diffusion-model-main/save/humanml_trans_enc_512/samples_humanml_trans_enc_512_000200000_seed10_the_person_is_hopping_like_a_rabbit/sample00_rep00.mp4
        pass

# %%
#!python -m sample.generate --model_path /content/drive/MyDrive/motion-diffusion-model-main/save/humanml_trans_enc_512/model000200000.pt --text_prompt "the person is hopping like a rabbit"

# %%
#!python -m sample.generate --model_path /content/drive/MyDrive/motion-diffusion-model-main/save/humanml_trans_enc_512/model000200000.pt --num_samples 10 --num_repetitions 3

# %%
# !pip install trimesh

# %%
# !pip install h5py

# %%
#!python -m visualize.render_mesh --input_path /content/drive/MyDrive/motion-diffusion-model-main/save/humanml_trans_enc_512/samples_humanml_trans_enc_512_000200000_seed10_the_person_is_hopping_like_a_rabbit/sample00_rep00.mp4

# %%
#!pip install streamlit
#!pip install pyngrok==4.1.1

# %%
#!npm install -g localtunnel

# %%
#%%writefile streamlit_app.py

# %%
#import streamlit as st
#from pyngrok import ngrok

# Your Streamlit app code here
#def main():
#    st.title("Avatar Generation")
#   action = st.text_input("Enter the action you want the avatar to perform:", "walking")
#   if st.button("Generate Avatar"):
        # Call your avatar generation function here
#       pass

# %%
if __name__ == "__main__":
    main()

# %%
# !nohup streamlit run streamlit_app.py &

# %%
from pyngrok import ngrok

# Paste your ngrok auth token here
ngrok.set_auth_token("2Z8Wvv0vZVRxR5u7s58uiWSMaQR_7htuWP9XPnNcPcvq3Uamf")

# Continue as before
public_url = ngrok.connect(port='8502')
public_url
